# %% [markdown]
# # Overview
# - Train an Autogluon predictor (autoML)

# %%
# Import necessary packages
from utils import pd, np, TabularPredictor, accuracy_score

# %%
# Import data 
train_df = pd.read_csv("../data/processed/train_data.csv")
test_df = pd.read_csv("../data/processed/test_data.csv")

# %%
# Set random seed for reproducibility
np.random.seed(42)

# %%
# Initialize autogluon tabular predictor
predictor = TabularPredictor(
    label='label',
    eval_metric='accuracy',
    path='../models/autogluon'
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="../models/autogluon"

# %%
# Train autogluon tabular predictor
predictor.fit(
    train_data=train_df,
    time_limit=600,  # 10 minutes time limit
    presets='medium_quality_faster_train',  # Use medium quality preset for faster training
    num_bag_folds=5,  # Number of folds for bagging
    num_stack_levels=2,  # Number of stacking levels
    verbosity=2,  # Show detailed training progress
)
# Out:
# Preset alias specified: 'medium_quality_faster_train' maps to 'medium_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.9.6
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 24.5.0: Tue Apr 22 19:54:49 PDT 2025; root:xnu-11417.121.6~2/RELEASE_ARM64_T6000
# CPU Count:          10
# Memory Avail:       34.22 GB / 64.00 GB (53.5%)
# Disk Space Avail:   853.49 GB / 926.35 GB (92.1%)
# ===================================================
# Presets specified: ['medium_quality_faster_train']
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "/Users/miriamlandau/Documents/predict_hand_imagery/models/autogluon"
# Train Data Rows:    168
# Train Data Columns: 258
# Label Column:       label
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [np.int64(0), np.int64(1)]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during Predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression', 'quantile'])
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    35042.43 MB
# 	Train Data (Original)  Memory Usage: 0.34 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 256 | ['ch1_std', 'ch1_mean', 'ch1_max', 'ch1_min', 'ch2_std', ...]
# 		('int', [])    :   1 | ['trial_id']
# 		('object', []) :   1 | ['subject_id']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) :   1 | ['subject_id']
# 		('float', [])    : 256 | ['ch1_std', 'ch1_mean', 'ch1_max', 'ch1_min', 'ch2_std', ...]
# 		('int', [])      :   1 | ['trial_id']
# 	0.1s = Fit runtime
# 	258 features in original data used to generate 258 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.33 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}],
# 	'XGB': [{}],
# 	'FASTAI': [{}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 3 stack levels (L1 to L3) ...
# Fitting 13 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 266.53s of the 599.84s of remaining time.
# 	0.4405	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 266.50s of the 599.82s of remaining time.
# 	0.506	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 266.47s of the 599.79s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.15%)
# 	0.7857	 = Validation score   (accuracy)
# 	0.48s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 264.40s of the 597.71s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.15%)
# 	0.7679	 = Validation score   (accuracy)
# 	0.49s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 262.35s of the 595.67s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.6964	 = Validation score   (accuracy)
# 	0.37s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 261.92s of the 595.23s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.6845	 = Validation score   (accuracy)
# 	0.27s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 261.59s of the 594.90s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=1.74%)
# 	0.7976	 = Validation score   (accuracy)
# 	5.26s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 254.82s of the 588.13s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.7143	 = Validation score   (accuracy)
# 	0.36s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 254.39s of the 587.71s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.6667	 = Validation score   (accuracy)
# 	0.32s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 254.01s of the 587.32s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.8036	 = Validation score   (accuracy)
# 	2.43s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 250.10s of the 583.41s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.31%)
# 	0.7619	 = Validation score   (accuracy)
# 	0.84s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 247.64s of the 580.96s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.7798	 = Validation score   (accuracy)
# 	2.3s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 243.29s of the 576.60s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.61%)
# 	0.7679	 = Validation score   (accuracy)
# 	1.72s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 573.22s of remaining time.
# 	Ensemble Weights: {'RandomForestGini_BAG_L1': 0.5, 'NeuralNetFastAI_BAG_L1': 0.5}
# 	0.8095	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 11 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 382.02s of the 573.17s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.16%)
# 	0.8274	 = Validation score   (accuracy)
# 	0.44s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 379.70s of the 570.84s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.16%)
# 	0.8214	 = Validation score   (accuracy)
# 	0.62s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 377.32s of the 568.47s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.7321	 = Validation score   (accuracy)
# 	0.36s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 376.89s of the 568.04s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.75	 = Validation score   (accuracy)
# 	0.3s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 376.53s of the 567.68s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=1.80%)
# 	0.8214	 = Validation score   (accuracy)
# 	7.49s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 367.47s of the 558.62s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.7381	 = Validation score   (accuracy)
# 	0.32s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 367.09s of the 558.23s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.7679	 = Validation score   (accuracy)
# 	0.29s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 366.73s of the 557.88s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.8095	 = Validation score   (accuracy)
# 	2.48s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 362.69s of the 553.83s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.32%)
# 	0.7976	 = Validation score   (accuracy)
# 	0.76s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 360.34s of the 551.49s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.7738	 = Validation score   (accuracy)
# 	3.0s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 355.43s of the 546.58s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.64%)
# 	0.7798	 = Validation score   (accuracy)
# 	1.7s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 543.25s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 1.0}
# 	0.8274	 = Validation score   (accuracy)
# 	0.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 11 L3 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L3 ... Training model for up to 543.22s of the 543.21s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.16%)
# 	0.8095	 = Validation score   (accuracy)
# 	0.46s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L3 ... Training model for up to 541.23s of the 541.22s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.16%)
# 	0.8393	 = Validation score   (accuracy)
# 	0.47s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L3 ... Training model for up to 539.17s of the 539.16s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.756	 = Validation score   (accuracy)
# 	0.42s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L3 ... Training model for up to 538.68s of the 538.68s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.7619	 = Validation score   (accuracy)
# 	0.35s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_BAG_L3 ... Training model for up to 538.27s of the 538.26s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=1.84%)
# 	0.8214	 = Validation score   (accuracy)
# 	6.13s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L3 ... Training model for up to 530.45s of the 530.45s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.756	 = Validation score   (accuracy)
# 	0.34s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L3 ... Training model for up to 530.05s of the 530.04s of remaining time.
# /Users/miriamlandau/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# 	0.7381	 = Validation score   (accuracy)
# 	0.31s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L3 ... Training model for up to 529.67s of the 529.66s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.7976	 = Validation score   (accuracy)
# 	2.58s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost_BAG_L3 ... Training model for up to 525.54s of the 525.53s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.33%)
# 	0.8274	 = Validation score   (accuracy)
# 	0.66s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L3 ... Training model for up to 522.97s of the 522.96s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.01%)
# 	0.7679	 = Validation score   (accuracy)
# 	2.12s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L3 ... Training model for up to 519.22s of the 519.21s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=0.65%)
# 	0.7738	 = Validation score   (accuracy)
# 	1.63s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L4 ... Training model for up to 360.00s of the 515.91s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L3': 1.0}
# 	0.8393	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 84.14s ... Best model: WeightedEnsemble_L4 | Estimated inference throughput: 76.8 rows/s (34 batch size)
# Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (168 rows).
# 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/miriamlandau/Documents/predict_hand_imagery/models/autogluon")

# %%
# Evaluate model performance
performance = predictor.evaluate(test_df)
performance
# Out:
# {'accuracy': 0.7619047619047619,
#  'balanced_accuracy': np.float64(0.7716346153846154),
#  'mcc': np.float64(0.5282450493547782),
#  'roc_auc': np.float64(0.78125),
#  'f1': 0.7222222222222222,
#  'precision': 0.65,
#  'recall': 0.8125}

# %%
# Display autogluon leadorboard
predictor.leaderboard(test_df)
# Out:
#                       model  score_test  score_val eval_metric  \
# 0    NeuralNetFastAI_BAG_L3    0.785714   0.797619    accuracy
# 1     NeuralNetTorch_BAG_L1    0.761905   0.779762    accuracy
# 2           CatBoost_BAG_L2    0.761905   0.821429    accuracy
# 3            XGBoost_BAG_L2    0.761905   0.797619    accuracy
# 4   RandomForestGini_BAG_L2    0.761905   0.732143    accuracy
# 5    NeuralNetFastAI_BAG_L2    0.761905   0.809524    accuracy
# 6           LightGBM_BAG_L3    0.761905   0.839286    accuracy
# 7       WeightedEnsemble_L4    0.761905   0.839286    accuracy
# 8           CatBoost_BAG_L3    0.761905   0.821429    accuracy
# 9   RandomForestGini_BAG_L3    0.761905   0.755952    accuracy
# 10  RandomForestEntr_BAG_L3    0.761905   0.761905    accuracy
# 11        LightGBMXT_BAG_L1    0.738095   0.785714    accuracy
# 12   NeuralNetFastAI_BAG_L1    0.738095   0.803571    accuracy
# 13      WeightedEnsemble_L2    0.738095   0.809524    accuracy
# 14          LightGBM_BAG_L2    0.738095   0.821429    accuracy
# 15     LightGBMLarge_BAG_L2    0.738095   0.779762    accuracy
# 16        LightGBMXT_BAG_L3    0.738095   0.809524    accuracy
# 17     LightGBMLarge_BAG_L3    0.738095   0.773810    accuracy
# 18           XGBoost_BAG_L3    0.738095   0.827381    accuracy
# 19    ExtraTreesGini_BAG_L3    0.738095   0.755952    accuracy
# 20    ExtraTreesEntr_BAG_L3    0.738095   0.738095    accuracy
# 21    NeuralNetTorch_BAG_L3    0.738095   0.767857    accuracy
# 22          LightGBM_BAG_L1    0.714286   0.767857    accuracy
# 23          CatBoost_BAG_L1    0.714286   0.797619    accuracy
# 24           XGBoost_BAG_L1    0.714286   0.761905    accuracy
# 25        LightGBMXT_BAG_L2    0.714286   0.827381    accuracy
# 26      WeightedEnsemble_L3    0.714286   0.827381    accuracy
# 27    ExtraTreesEntr_BAG_L2    0.714286   0.767857    accuracy
# 28  RandomForestEntr_BAG_L2    0.714286   0.750000    accuracy
# 29    NeuralNetTorch_BAG_L2    0.714286   0.773810    accuracy
# 30  RandomForestEntr_BAG_L1    0.690476   0.684524    accuracy
# 31    ExtraTreesGini_BAG_L2    0.690476   0.738095    accuracy
# 32    ExtraTreesEntr_BAG_L1    0.619048   0.666667    accuracy
# 33    ExtraTreesGini_BAG_L1    0.619048   0.714286    accuracy
# 34  RandomForestGini_BAG_L1    0.619048   0.696429    accuracy
# 35    KNeighborsUnif_BAG_L1    0.595238   0.440476    accuracy
# 36     LightGBMLarge_BAG_L1    0.595238   0.767857    accuracy
# 37    KNeighborsDist_BAG_L1    0.571429   0.505952    accuracy
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.584514       0.610228  29.397866                 0.037381
# 1         0.110924       0.112273   2.304106                 0.110924
# 2         0.283238       0.309759  19.550223                 0.015824
# 3         0.294491       0.295251  12.816848                 0.027076
# 4         0.299389       0.326428  12.416779                 0.031975
# 5         0.315873       0.313011  14.535238                 0.048459
# 6         0.556002       0.587927  27.292856                 0.008869
# 7         0.556649       0.588331  27.330467                 0.000648
# 8         0.562952       0.611860  32.951194                 0.015819
# 9         0.577109       0.625844  27.236423                 0.029976
# 10        0.579997       0.626904  27.164618                 0.032864
# 11        0.010162       0.008447   0.478543                 0.010162
# 12        0.038001       0.026358   2.434548                 0.038001
# 13        0.070687       0.070567   2.844423                 0.000767
# 14        0.276434       0.292140  12.675601                 0.009020
# 15        0.280123       0.292311  13.760315                 0.012708
# 16        0.555343       0.588062  27.278444                 0.008210
# 17        0.560309       0.589524  28.453168                 0.013177
# 18        0.572793       0.591717  27.484093                 0.025660
# 19        0.578478       0.624023  27.154323                 0.031345
# 20        0.580226       0.623201  27.132270                 0.033093
# 21        0.659377       0.692686  28.938554                 0.112244
# 22        0.009110       0.008379   0.486596                 0.009110
# 23        0.015257       0.028185   5.262927                 0.015257
# 24        0.025202       0.013980   0.841735                 0.025202
# 25        0.275631       0.292120  12.500540                 0.008217
# 26        0.276300       0.292461  12.531912                 0.000669
# 27        0.300226       0.326832  12.348204                 0.032812
# 28        0.300488       0.325927  12.355395                 0.033073
# 29        0.381671       0.403738  15.057142                 0.114257
# 30        0.031554       0.043823   0.270186                 0.031554
# 31        0.300456       0.327525  12.373027                 0.033041
# 32        0.030221       0.044388   0.320224                 0.030221
# 33        0.030294       0.045952   0.356484                 0.030294
# 34        0.031919       0.043742   0.369932                 0.031919
# 35        0.003970       0.002167   0.008917                 0.003970
# 36        0.014734       0.009672   1.718569                 0.014734
# 37        0.005655       0.002512   0.009138                 0.005655
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.032283           2.578760            3       True
# 1                 0.112273           2.304106            1       True
# 2                 0.028310           7.492809            2       True
# 3                 0.013802           0.759434            2       True
# 4                 0.044979           0.359366            2       True
# 5                 0.031562           2.477824            2       True
# 6                 0.009983           0.473750            3       True
# 7                 0.000404           0.037611            4       True
# 8                 0.033916           6.132087            3       True
# 9                 0.047900           0.417316            3       True
# 10                0.048960           0.345511            3       True
# 11                0.008447           0.478543            1       True
# 12                0.026358           2.434548            1       True
# 13                0.000467           0.039943            2       True
# 14                0.010692           0.618188            2       True
# 15                0.010862           1.702902            2       True
# 16                0.010118           0.459337            3       True
# 17                0.011580           1.634061            3       True
# 18                0.013772           0.664987            3       True
# 19                0.046079           0.335216            3       True
# 20                0.045257           0.313163            3       True
# 21                0.114742           2.119447            3       True
# 22                0.008379           0.486596            1       True
# 23                0.028185           5.262927            1       True
# 24                0.013980           0.841735            1       True
# 25                0.010671           0.443126            2       True
# 26                0.000341           0.031372            3       True
# 27                0.045383           0.290791            2       True
# 28                0.044478           0.297981            2       True
# 29                0.122289           2.999728            2       True
# 30                0.043823           0.270186            1       True
# 31                0.046076           0.315613            2       True
# 32                0.044388           0.320224            1       True
# 33                0.045952           0.356484            1       True
# 34                0.043742           0.369932            1       True
# 35                0.002167           0.008917            1       True
# 36                0.009672           1.718569            1       True
# 37                0.002512           0.009138            1       True
#
#     fit_order
# 0          34
# 1          12
# 2          19
# 3          23
# 4          17
# 5          22
# 6          28
# 7          38
# 8          31
# 9          29
# 10         30
# 11          3
# 12         10
# 13         14
# 14         16
# 15         25
# 16         27
# 17         37
# 18         35
# 19         32
# 20         33
# 21         36
# 22          4
# 23          7
# 24         11
# 25         15
# 26         26
# 27         21
# 28         18
# 29         24
# 30          6
# 31         20
# 32          9
# 33          8
# 34          5
# 35          1
# 36         13
# 37          2

# %%
# Display feature importance
feature_importance = predictor.feature_importance(train_df) 
feature_importance.sort_values(by='importance', ascending=False).head()
# runs too long
# Out:
# Computing feature importance via permutation shuffling for 258 features using 168 rows with 5 shuffle sets...
# 	898.08s	= Expected runtime (179.62s per shuffle set)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Display feature importance
# ----> 2 feature_importance = predictor.feature_importance(train_df)
#       3 feature_importance.sort_values(by='importance', ascending=False).head()
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:3428, in TabularPredictor.feature_importance(self, data, model, features, feature_stage, subsample_size, time_limit, num_shuffle_sets, include_confidence_band, confidence_level, silent)
#    3425 if num_shuffle_sets is None:
#    3426     num_shuffle_sets = 10 if time_limit else 5
# -> 3428 fi_df = self._learner.get_feature_importance(
#    3429     model=model,
#    3430     X=data,
#    3431     features=features,
#    3432     feature_stage=feature_stage,
#    3433     subsample_size=subsample_size,
#    3434     time_limit=time_limit,
#    3435     num_shuffle_sets=num_shuffle_sets,
#    3436     silent=silent,
#    3437 )
#    3439 if include_confidence_band:
#    3440     if confidence_level <= 0.5 or confidence_level >= 1.0:
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/learner/abstract_learner.py:1010, in AbstractTabularLearner.get_feature_importance(self, model, X, y, features, feature_stage, subsample_size, silent, **kwargs)
#    1007         X = X.drop(columns=unused_features)
#    1009     if feature_stage == "original":
# -> 1010         return trainer._get_feature_importance_raw(
#    1011             model=model, X=X, y=y, features=features, subsample_size=subsample_size, transform_func=self.transform_features, silent=silent, **kwargs
#    1012         )
#    1013     X = self.transform_features(X)
#    1014 else:
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/trainer/abstract_trainer.py:3520, in AbstractTabularTrainer._get_feature_importance_raw(self, X, y, model, eval_metric, **kwargs)
#    3518 model: AbstractModel = self.load_model(model)
#    3519 predict_func_kwargs = dict(model=model)
# -> 3520 return compute_permutation_feature_importance(
#    3521     X=X,
#    3522     y=y,
#    3523     predict_func=predict_func,
#    3524     predict_func_kwargs=predict_func_kwargs,
#    3525     eval_metric=eval_metric,
#    3526     quantile_levels=self.quantile_levels,
#    3527     **kwargs,
#    3528 )
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/core/utils/utils.py:1025, in compute_permutation_feature_importance(X, y, predict_func, eval_metric, features, subsample_size, num_shuffle_sets, predict_func_kwargs, transform_func, transform_func_kwargs, time_limit, silent, log_prefix, importance_as_list, random_state, **kwargs)
#    1023 else:
#    1024     X_raw_transformed = X_raw if transform_func is None else transform_func(X_raw, **transform_func_kwargs)
# -> 1025 y_pred = predict_func(X_raw_transformed, **predict_func_kwargs)
#    1027 row_index = 0
#    1028 for feature in parallel_computed_features:
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/trainer/abstract_trainer.py:973, in AbstractTabularTrainer.predict(self, X, model)
#     971 if model is None:
#     972     model = self._get_best()
# --> 973 return self._predict_model(X=X, model=model)
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/trainer/abstract_trainer.py:3331, in AbstractTabularTrainer._predict_model(self, X, model, model_pred_proba_dict)
#    3330 def _predict_model(self, X: pd.DataFrame, model: str, model_pred_proba_dict: dict | None = None) -> np.ndarray:
# -> 3331     y_pred_proba = self._predict_proba_model(X=X, model=model, model_pred_proba_dict=model_pred_proba_dict)
#    3332     return get_pred_from_proba(y_pred_proba=y_pred_proba, problem_type=self.problem_type)
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/trainer/abstract_trainer.py:3335, in AbstractTabularTrainer._predict_proba_model(self, X, model, model_pred_proba_dict)
#    3334 def _predict_proba_model(self, X: pd.DataFrame, model: str, model_pred_proba_dict: dict | None = None) -> np.ndarray:
# -> 3335     model_pred_proba_dict = self.get_model_pred_proba_dict(X=X, models=[model], model_pred_proba_dict=model_pred_proba_dict)
#    3336     if not isinstance(model, str):
#    3337         model = model.name
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/trainer/abstract_trainer.py:1253, in AbstractTabularTrainer.get_model_pred_proba_dict(self, X, models, model_pred_proba_dict, model_pred_time_dict, record_pred_time, use_val_cache)
#    1251 if isinstance(model, StackerEnsembleModel):
#    1252     preprocess_kwargs = dict(infer=False, model_pred_proba_dict=model_pred_proba_dict)
# -> 1253     model_pred_proba_dict[model_name] = model.predict_proba(X, **preprocess_kwargs)
#    1254 else:
#    1255     model_pred_proba_dict[model_name] = model.predict_proba(X)
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py:1173, in AbstractModel.predict_proba(self, X, normalize, record_time, **kwargs)
#    1148 """
#    1149 Returns class prediction probabilities of X.
#    1150 For binary problems, this returns the positive class label probability as a 1d numpy array.
#    (...)
#    1169     The prediction probabilities
#    1170 """
#    1171 time_start = time.time() if record_time else None
# -> 1173 y_pred_proba = self._predict_proba_internal(X=X, normalize=normalize, **kwargs)
#    1175 if self.params_aux.get("temperature_scalar", None) is not None:
#    1176     y_pred_proba = self._apply_temperature_scaling(y_pred_proba)
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py:591, in BaggedEnsembleModel._predict_proba_internal(self, X, normalize, **kwargs)
#     589 for model in self.models[1:]:
#     590     model = self.load_child(model)
# --> 591     y_pred_proba += model.predict_proba(X=X, preprocess_nonadaptive=False, normalize=normalize)
#     592 y_pred_proba = y_pred_proba / self.n_children
#     593 return y_pred_proba
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py:1173, in AbstractModel.predict_proba(self, X, normalize, record_time, **kwargs)
#    1148 """
#    1149 Returns class prediction probabilities of X.
#    1150 For binary problems, this returns the positive class label probability as a 1d numpy array.
#    (...)
#    1169     The prediction probabilities
#    1170 """
#    1171 time_start = time.time() if record_time else None
# -> 1173 y_pred_proba = self._predict_proba_internal(X=X, normalize=normalize, **kwargs)
#    1175 if self.params_aux.get("temperature_scalar", None) is not None:
#    1176     y_pred_proba = self._apply_temperature_scaling(y_pred_proba)
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py:1187, in AbstractModel._predict_proba_internal(self, X, normalize, **kwargs)
#    1185 if normalize is None:
#    1186     normalize = self.normalize_pred_probas
# -> 1187 y_pred_proba = self._predict_proba(X=X, **kwargs)
#    1188 if normalize:
#    1189     y_pred_proba = normalize_pred_probas(y_pred_proba, self.problem_type)
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py:215, in XGBoostModel._predict_proba(self, X, num_cpus, **kwargs)
#     214 def _predict_proba(self, X, num_cpus=-1, **kwargs):
# --> 215     X = self.preprocess(X, **kwargs)
#     216     if self.problem_type in [MULTICLASS, SOFTCLASS]:
#     217         # Bug fix for "xgboost>=2,<2.0.3" : https://github.com/dmlc/xgboost/issues/9807
#     218         self.model.set_params(n_jobs=num_cpus, objective="multi:softprob")
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py:546, in AbstractModel.preprocess(self, X, preprocess_nonadaptive, preprocess_stateful, **kwargs)
#     544     X = self._preprocess_nonadaptive(X, **kwargs)
#     545 if preprocess_stateful:
# --> 546     X = self._preprocess(X, **kwargs)
#     547 return X
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py:74, in XGBoostModel._preprocess(self, X, is_train, max_category_levels, **kwargs)
#      71         self._ohe_generator.fit(X)
#      73 if self._ohe:
# ---> 74     X = self._ohe_generator.transform(X)
#      76 return X
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/autogluon/tabular/models/xgboost/xgboost_utils.py:157, in OheFeatureGenerator.transform(self, X, y)
#     155     X_list.append(self.ohe_encs.transform(X[self.cat_cols]))
#     156 if self.other_cols:
# --> 157     X_list.append(csr_matrix(X[self.other_cols]))
#     158 return hstack(X_list, format="csr")
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/scipy/sparse/_compressed.py:93, in _cs_matrix.__init__(self, arg1, shape, dtype, copy)
#      89         raise ValueError(
#      90             f"CSC arrays don't support {arg1.ndim}D input. Use 2D"
#      91         )
#      92     coo = self._coo_container(arg1, dtype=dtype)
# ---> 93     arrays = coo._coo_to_compressed(self._swap)
#      94     self.indptr, self.indices, self.data, self._shape = arrays
#      96 # Read matrix dimensions given, if any
#
# File ~/Documents/predict_hand_imagery/venv/lib/python3.9/site-packages/scipy/sparse/_coo.py:366, in _coo_base._coo_to_compressed(self, swap)
#     363 indices = np.empty_like(minor, dtype=idx_dtype)
#     364 data = np.empty_like(self.data, dtype=self.dtype)
# --> 366 coo_tocsr(M, N, nnz, major, minor, self.data, indptr, indices, data)
#     367 return indptr, indices, data, self.shape
#
# KeyboardInterrupt:

# %% [markdown]
# # Key Takeways
#
# - autogluon performs with an accuracy of 0.76 with a stacked ensemble
